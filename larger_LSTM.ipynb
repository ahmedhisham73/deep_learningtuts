# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedhisham73/deep_learningtuts/blob/master/larger_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
# load ascii text and covert to lowercase
filename = "/content/shakes2.txt"
raw_text = open(filename, 'r', encoding='utf-8').read()
raw_text = raw_text.lower()
# create mapping of unique chars to integers
chars = sorted(list(set(raw_text)))
char_to_int = dict((c, i) for i, c in enumerate(chars))
# summarize the loaded data
n_chars = len(raw_text)
n_vocab = len(chars)
print ("Total Characters: ", n_chars)
print ("Total Vocab: ", n_vocab)
# prepare the dataset of input to output pairs encoded as integers
seq_length = 100
dataX = []
dataY = []
for i in range(0, n_chars - seq_length, 1):
	seq_in = raw_text[i:i + seq_length]
	seq_out = raw_text[i + seq_length]
	dataX.append([char_to_int[char] for char in seq_in])
	dataY.append(char_to_int[seq_out])
n_patterns = len(dataX)
print ("Total Patterns: ", n_patterns)
# reshape X to be [samples, time steps, features]
X = numpy.reshape(dataX, (n_patterns, seq_length, 1))
# normalize
X = X / float(n_vocab)
# one hot encode the output variable
y = np_utils.to_categorical(dataY)
# define the LSTM model
model = Sequential()
model.add(LSTM(256, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(256))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')
# define the checkpoint
filepath="weights-improvement-{epoch:02d}-{loss:.4f}-bigger.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]
# fit the model
model.fit(X, y, epochs=25, batch_size=64, callbacks=callbacks_list)
# Out:
# Total Characters:  162329
# Total Vocab:  64
# Total Patterns:  162229
# Epoch 1/25
# 162229/162229 [==============================] - 931s 6ms/step - loss: 2.8426
#
# Epoch 00001: loss improved from inf to 2.84265, saving model to weights-improvement-01-2.8426-bigger.hdf5
# Epoch 2/25
# 162229/162229 [==============================] - 931s 6ms/step - loss: 2.5680
#
# Epoch 00002: loss improved from 2.84265 to 2.56800, saving model to weights-improvement-02-2.5680-bigger.hdf5
# Epoch 3/25
# 162229/162229 [==============================] - 923s 6ms/step - loss: 2.4191
#
# Epoch 00003: loss improved from 2.56800 to 2.41906, saving model to weights-improvement-03-2.4191-bigger.hdf5
# Epoch 4/25
# 162229/162229 [==============================] - 911s 6ms/step - loss: 2.3056
#
# Epoch 00004: loss improved from 2.41906 to 2.30562, saving model to weights-improvement-04-2.3056-bigger.hdf5
# Epoch 5/25
# 162229/162229 [==============================] - 920s 6ms/step - loss: 2.2182
#
# Epoch 00005: loss improved from 2.30562 to 2.21820, saving model to weights-improvement-05-2.2182-bigger.hdf5
# Epoch 6/25
# 162229/162229 [==============================] - 930s 6ms/step - loss: 2.1439
#
# Epoch 00006: loss improved from 2.21820 to 2.14386, saving model to weights-improvement-06-2.1439-bigger.hdf5
# Epoch 7/25
# 162229/162229 [==============================] - 914s 6ms/step - loss: 2.0838
#
# Epoch 00007: loss improved from 2.14386 to 2.08378, saving model to weights-improvement-07-2.0838-bigger.hdf5
# Epoch 8/25
# 162229/162229 [==============================] - 932s 6ms/step - loss: 2.0345
#
# Epoch 00008: loss improved from 2.08378 to 2.03452, saving model to weights-improvement-08-2.0345-bigger.hdf5
# Epoch 9/25
# 162229/162229 [==============================] - 929s 6ms/step - loss: 1.9890
#
# Epoch 00009: loss improved from 2.03452 to 1.98898, saving model to weights-improvement-09-1.9890-bigger.hdf5
# Epoch 10/25
# 162229/162229 [==============================] - 933s 6ms/step - loss: 1.9530
#
# Epoch 00010: loss improved from 1.98898 to 1.95304, saving model to weights-improvement-10-1.9530-bigger.hdf5
# Epoch 11/25
# 162229/162229 [==============================] - 929s 6ms/step - loss: 1.9151
#
# Epoch 00011: loss improved from 1.95304 to 1.91507, saving model to weights-improvement-11-1.9151-bigger.hdf5
# Epoch 12/25
# 162229/162229 [==============================] - 936s 6ms/step - loss: 1.8888
#
# Epoch 00012: loss improved from 1.91507 to 1.88876, saving model to weights-improvement-12-1.8888-bigger.hdf5
# Epoch 13/25
# 162229/162229 [==============================] - 938s 6ms/step - loss: 1.8598
#
# Epoch 00013: loss improved from 1.88876 to 1.85980, saving model to weights-improvement-13-1.8598-bigger.hdf5
# Epoch 14/25
# 162229/162229 [==============================] - 935s 6ms/step - loss: 1.8306
#
# Epoch 00014: loss improved from 1.85980 to 1.83059, saving model to weights-improvement-14-1.8306-bigger.hdf5
# Epoch 15/25
# 162229/162229 [==============================] - 939s 6ms/step - loss: 1.8050
#
# Epoch 00015: loss improved from 1.83059 to 1.80497, saving model to weights-improvement-15-1.8050-bigger.hdf5
# Epoch 16/25
# 162229/162229 [==============================] - 923s 6ms/step - loss: 1.7863
#
# Epoch 00016: loss improved from 1.80497 to 1.78625, saving model to weights-improvement-16-1.7863-bigger.hdf5
# Epoch 17/25
# 162229/162229 [==============================] - 912s 6ms/step - loss: 1.7700
#
# Epoch 00017: loss improved from 1.78625 to 1.76996, saving model to weights-improvement-17-1.7700-bigger.hdf5
# Epoch 18/25
#    448/162229 [..............................] - ETA: 15:16 - loss: 1.5949
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-079164d6593e> in <module>()
#      48 callbacks_list = [checkpoint]
#      49 # fit the model
# ---> 50 model.fit(X, y, epochs=25, batch_size=64, callbacks=callbacks_list)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1176                                         steps_per_epoch=steps_per_epoch,
#    1177                                         validation_steps=validation_steps,
# -> 1178                                         validation_freq=validation_freq)
#    1179
#    1180     def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     202                     ins_batch[i] = ins_batch[i].toarray()
#     203
# --> 204                 outs = fit_function(ins_batch)
#     205                 outs = to_list(outs)
#     206                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
	
# Load Larger LSTM network and generate text
import sys
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
# load ascii text and covert to lowercase
filename = "/content/shakes2.txt"
raw_text = open(filename, 'r', encoding='utf-8').read()
raw_text = raw_text.lower()
# create mapping of unique chars to integers, and a reverse mapping
chars = sorted(list(set(raw_text)))
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))
# summarize the loaded data
n_chars = len(raw_text)
n_vocab = len(chars)
print ("Total Characters: ", n_chars)
print ("Total Vocab: ", n_vocab)
# prepare the dataset of input to output pairs encoded as integers
seq_length = 100
dataX = []
dataY = []
for i in range(0, n_chars - seq_length, 1):
	seq_in = raw_text[i:i + seq_length]
	seq_out = raw_text[i + seq_length]
	dataX.append([char_to_int[char] for char in seq_in])
	dataY.append(char_to_int[seq_out])
n_patterns = len(dataX)
print ("Total Patterns: ", n_patterns)
# reshape X to be [samples, time steps, features]
X = numpy.reshape(dataX, (n_patterns, seq_length, 1))
# normalize
X = X / float(n_vocab)
# one hot encode the output variable
y = np_utils.to_categorical(dataY)
# define the LSTM model
model = Sequential()
model.add(LSTM(256, input_shape=(X.shape[1], X.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(256))
model.add(Dropout(0.2))
model.add(Dense(y.shape[1], activation='softmax'))
# load the network weights
filename = "/content/weights-improvement-17-1.7700-bigger.hdf5"
model.load_weights(filename)
model.compile(loss='categorical_crossentropy', optimizer='adam')
# pick a random seed
start = numpy.random.randint(0, len(dataX)-1)
pattern = dataX[start]
print ("Seed:")
print ("\"", ''.join([int_to_char[value] for value in pattern]), "\"")
# generate characters
for i in range(1000):
	x = numpy.reshape(pattern, (1, len(pattern), 1))
	x = x / float(n_vocab)
	prediction = model.predict(x, verbose=0)
	index = numpy.argmax(prediction)
	result = int_to_char[index]
	seq_in = [int_to_char[value] for value in pattern]
	sys.stdout.write(result)
	pattern.append(index)
	pattern = pattern[1:len(pattern)]
print ("\nDone.")
# Out:
# Total Characters:  162329
# Total Vocab:  64
# Total Patterns:  162229
# Seed:
# " minim rest, one, two, and the third in
# your bosom: the very butcher of a silk button, a duellist, a  "
# couster of the county paris and have the county with pf the project gutenberg-tm electronic works in the project gutenberg-tm electronic works in the project gutenberg-tm electronic works in the project gutenberg-tm electronic works in the project gutenberg-tm electronic works in the project gutenberg-tm electronic works in the project gutenberg-tm electronic works in the project gutenberg
